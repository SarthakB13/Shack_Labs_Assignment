# %%
# importing libraries
import pandas as pd
import re
import numpy as np
! pip install thefuzz
from thefuzz import fuzz, process
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# /usr/local/lib/python3.8/dist-packages/thefuzz/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# reading amazon data
amazon = pd.read_csv('/content/amz_com-ecommerce_sample.csv', encoding='ISO-8859-1')
amazon
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
# getting amazon columns info
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             20000 non-null  int64
#  7   discounted_price         20000 non-null  int64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
amazon.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
# seeing if amazon dataset has any N/A values
amazon.isna().sum()
# Out:
# uniq_id                       0
# crawl_timestamp               0
# product_url                   0
# product_name                  0
# product_category_tree         0
# pid                           0
# retail_price                  0
# discounted_price              0
# image                         3
# is_FK_Advantage_product       0
# description                   2
# product_rating                0
# overall_rating                0
# brand                      5864
# product_specifications       14
# dtype: int64

# %%
# reading flipkart data
flipkart = pd.read_csv('/content/flipkart_com-ecommerce_sample.csv')
flipkart
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
flipkart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
flipkart.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
# getting the input from user
string = input("Enter product name : ")
# Out:
# Enter product name : bellies

# %%
amazondf = pd.DataFrame(process.extract(string, amazon['product_name'],limit = 10,scorer=fuzz.token_sort_ratio), 
                         columns = ['product_name', 'match score','id'])
amazondf
# Out:
#      product_name  match score     id
# 0      AW Bellies           82      2
# 1   INC.5 BELLIES           70  17660
# 2  Ladela Bellies           67     10
# 3  Bonzer Bellies           67    532
# 4  Bonzer Bellies           67    546
# 5  Bonzer Bellies           67    547
# 6  Treppe Bellies           67   3041
# 7  Kanvas Bellies           67   3042
# 8  Treppe Bellies           67   3055
# 9  Treppe Bellies           67   3058

# %%
flipkartdf = pd.DataFrame(process.extract(string, flipkart['product_name'],limit = 10,scorer=fuzz.token_sort_ratio), 
                         columns = ['product_name', 'match score','id'])
flipkartdf
# Out:
#      product_name  match score     id
# 0      AW Bellies           82      2
# 1   Inc.5 Bellies           70  17660
# 2  Ladela Bellies           67     10
# 3  Bonzer Bellies           67    532
# 4  Bonzer Bellies           67    546
# 5  Bonzer Bellies           67    547
# 6  Treppe Bellies           67   3041
# 7  Kanvas Bellies           67   3042
# 8  Treppe Bellies           67   3055
# 9  Treppe Bellies           67   3058

# %%
amazonoutput = amazon.loc[amazondf['id']]
# renaming coloumns
amazonoutput = amazonoutput.rename(columns={'product_name':'Product name in Amazon',
                                            'retail_price':'Retail Price in Amazon',
                                            'discounted_price':'Discounted Price in Amazon'})
amazonoutput[['Product name in Amazon', 'Retail Price in Amazon', 'Discounted Price in Amazon']]
# Out:
#       Product name in Amazon  Retail Price in Amazon  \
# 2                 AW Bellies                     991
# 17660          INC.5 BELLIES                    1583
# 10            Ladela Bellies                    1705
# 532           Bonzer Bellies                     680
# 546           Bonzer Bellies                     995
# 547           Bonzer Bellies                     992
# 3041          Treppe Bellies                     988
# 3042          Kanvas Bellies                    1592
# 3055          Treppe Bellies                     989
# 3058          Treppe Bellies                     986
#
#        Discounted Price in Amazon
# 2                             551
# 17660                         790
# 10                           1119
# 532                           474
# 546                           597
# 547                           611
# 3041                          501
# 3042                         2021
# 3055                          454
# ...

# %%
flipkartoutput = flipkart.loc[flipkartdf['id']]
# renaming coloumns
flipkartoutput = flipkartoutput.rename(columns={'product_name':'Product name in Flipkart',
                                            'retail_price':'Retail Price in Flipkart',
                                            'discounted_price':'Discounted Price in Flipkart'})
flipkartoutput[['Product name in Flipkart', 'Retail Price in Flipkart', 'Discounted Price in Flipkart']]
# Out:
#       Product name in Flipkart  Retail Price in Flipkart  \
# 2                   AW Bellies                     999.0
# 17660            Inc.5 Bellies                    1590.0
# 10              Ladela Bellies                    1724.0
# 532             Bonzer Bellies                     699.0
# 546             Bonzer Bellies                     999.0
# 547             Bonzer Bellies                     999.0
# 3041            Treppe Bellies                     999.0
# 3042            Kanvas Bellies                    1600.0
# 3055            Treppe Bellies                     999.0
# 3058            Treppe Bellies                     999.0
#
#        Discounted Price in Flipkart
# 2                             499.0
# 17660                         636.0
# 10                            950.0
# 532                           399.0
# 546                           499.0
# 547                           499.0
# 3041                          399.0
# 3042                         1600.0
# ...

# %%
merge = pd.concat([amazonoutput[['Product name in Amazon', 'Retail Price in Amazon', 'Discounted Price in Amazon']],
                   flipkartoutput[['Product name in Flipkart', 'Retail Price in Flipkart', 'Discounted Price in Flipkart']]],
                  axis = 1)
merge
# Out:
#       Product name in Amazon  Retail Price in Amazon  \
# 2                 AW Bellies                     991
# 17660          INC.5 BELLIES                    1583
# 10            Ladela Bellies                    1705
# 532           Bonzer Bellies                     680
# 546           Bonzer Bellies                     995
# 547           Bonzer Bellies                     992
# 3041          Treppe Bellies                     988
# 3042          Kanvas Bellies                    1592
# 3055          Treppe Bellies                     989
# 3058          Treppe Bellies                     986
#
#        Discounted Price in Amazon Product name in Flipkart  \
# 2                             551               AW Bellies
# 17660                         790            Inc.5 Bellies
# 10                           1119           Ladela Bellies
# 532                           474           Bonzer Bellies
# 546                           597           Bonzer Bellies
# ...

# %%
# The other methods to get similarity include :
# TF-IDF
# word2vec
# doc2vect
# Transformer-BERT
